# %%
# R Notebook
if(!require(tidyverse)) {
  install.packages("tidyverse")
  library(tidyverse)
}
if(!require(ggplot2)) {
  install.packages("ggplot2")
  library(ggplot2)
}
if(!require(ggplot2)) {
  install.packages("ggplot2")
  library(ggplot2)
}
